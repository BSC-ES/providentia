# %%
# import Providentia
import providentia as prv

# %%
# magic to make plots appear inline
# %matplotlib inline

# %%
# read and filter data from .conf 
provi_lev15_bahadur = prv.load('foci_aeronet_BC.conf', section='AERONET1.5_BAHADUR')
provi_lev15_schuster = prv.load('foci_aeronet_BC.conf', section='AERONET1.5_SCHUSTER')
provi_lev15f_bahadur = prv.load('foci_aeronet_BC.conf', section='AERONET1.5_BAHADUR_FLAGL2')
provi_lev15f_schuster = prv.load('foci_aeronet_BC.conf', section='AERONET1.5_SCHUSTER_FLAGL2')
provi_lev20_bahadur = prv.load('foci_aeronet_BC.conf', section='AERONET2.0_BAHADUR')
provi_lev20_schuster = prv.load('foci_aeronet_BC.conf', section='AERONET2.0_SCHUSTER')
# Out:
# Generating file trees...
# Reading data
# check forecast conf: True dashboard_interactive: False
# return
# UPDATE PP READ/SETUP
# DATA LABELS BEFORE: ['observations']
# PLOTTING PARAMS AFTER: dict_keys(['observations'])
# DATA LABELS AFTER: ['observations']
#
# OBSERVATIONS
#  - AERONET_v3_lev1.5|absod440bcbahadur
#
# Resetting data filters to when class was initialised, loading AERONET1.5_BAHADUR subsection filters.
# Filtering data
# Generating file trees...
# Reading data
# check forecast conf: True dashboard_interactive: False
# return
# UPDATE PP READ/SETUP
# DATA LABELS BEFORE: ['observations']
# PLOTTING PARAMS AFTER: dict_keys(['observations'])
# DATA LABELS AFTER: ['observations']
#
# OBSERVATIONS
#  - AERONET_v3_lev1.5|absod440bcschuster
#
# Resetting data filters to when class was initialised, loading AERONET1.5_SCHUSTER subsection filters.
# Filtering data
# Generating file trees...
# Reading data
# check forecast conf: True dashboard_interactive: False
# return
# ...

# %%
provi_lev15_bahadur.plot('periodic-Mean', title='AERONET LEV1.5 BAHADUR')

# %%
provi_lev15_schuster.plot('periodic-Mean', title='AERONET LEV1.5 SCHUSTER')

# %%
provi_lev15f_bahadur.plot('periodic-Mean', title='AERONET LEV1.5 BAHADUR L2 FLAGS')

# %%
provi_lev15f_schuster.plot('periodic-Mean', title='AERONET LEV1.5 SCHUSTER L2 FLAGS')

# %%
provi_lev20_bahadur.plot('periodic-Mean', title='AERONET LEV2.0 BAHADUR')

# %%
provi_lev20_schuster.plot('periodic-Mean', title='AERONET LEV2.0 SCHUSTER')

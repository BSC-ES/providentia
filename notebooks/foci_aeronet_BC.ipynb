# %%
# import Providentia
import providentia as prv

# %%
# magic to make plots appear inline
# %matplotlib inline

# %%
# initialise objects
provi_lev15_bahadur = prv.Providentia('foci_aeronet_BC.conf', section='AERONET1.5_BAHADUR')
provi_lev15_schuster = prv.Providentia('foci_aeronet_BC.conf', section='AERONET1.5_SCHUSTER')
provi_lev15f_bahadur = prv.Providentia('foci_aeronet_BC.conf', section='AERONET1.5_BAHADUR_FLAGL2')
provi_lev15f_schuster = prv.Providentia('foci_aeronet_BC.conf', section='AERONET1.5_SCHUSTER_FLAGL2')
provi_lev20_bahadur = prv.Providentia('foci_aeronet_BC.conf', section='AERONET2.0_BAHADUR')
provi_lev20_schuster = prv.Providentia('foci_aeronet_BC.conf', section='AERONET2.0_SCHUSTER')

# %%
# read and filter data
provi_lev15_bahadur.load()
provi_lev15_schuster.load()
provi_lev15f_bahadur.load()
provi_lev15f_schuster.load()
provi_lev20_bahadur.load()
provi_lev20_schuster.load()
# Out:
# Updating file tree /Users/denebowdalo/providentia/settings/internal/ghost_filetree_1.5.2.json...
# Updating file tree /Users/denebowdalo/providentia/settings/internal/nonghost_filetree.json...
# Reading data
#
# OBSERVATIONS
#  - AERONET_v3_lev1.5|absod440bcbahadur
#
# Resetting data filters to when class was initialised, loading AERONET1.5_BAHADUR subsection filters.
# Filtering data
# Updating file tree /Users/denebowdalo/providentia/settings/internal/ghost_filetree_1.5.2.json...
# Updating file tree /Users/denebowdalo/providentia/settings/internal/nonghost_filetree.json...
# Reading data
#
# OBSERVATIONS
#  - AERONET_v3_lev1.5|absod440bcschuster
#
# Resetting data filters to when class was initialised, loading AERONET1.5_SCHUSTER subsection filters.
# Filtering data
# Updating file tree /Users/denebowdalo/providentia/settings/internal/ghost_filetree_1.5.2.json...
# Updating file tree /Users/denebowdalo/providentia/settings/internal/nonghost_filetree.json...
# Reading data
#
# ...

# %%
provi_lev15_bahadur.plot('periodic-Mean', title='AERONET LEV1.5 BAHADUR')

# %%
provi_lev15_schuster.plot('periodic-Mean', title='AERONET LEV1.5 SCHUSTER')

# %%
provi_lev15f_bahadur.plot('periodic-Mean', title='AERONET LEV1.5 BAHADUR L2 FLAGS')

# %%
provi_lev15f_schuster.plot('periodic-Mean', title='AERONET LEV1.5 SCHUSTER L2 FLAGS')

# %%
provi_lev20_bahadur.plot('periodic-Mean', title='AERONET LEV2.0 BAHADUR')

# %%
provi_lev20_schuster.plot('periodic-Mean', title='AERONET LEV2.0 SCHUSTER')

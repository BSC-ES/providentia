# %%
# import Providentia
import providentia as prv
# Out:
# /home/bsc/bsc032781/.local/lib/python3.11/site-packages/pypdf/_crypt_providers/_cryptography.py:32: CryptographyDeprecationWarning: ARC4 has been moved to cryptography.hazmat.decrepit.ciphers.algorithms.ARC4 and will be removed from cryptography.hazmat.primitives.ciphers.algorithms in 48.0.0.
#   from cryptography.hazmat.primitives.ciphers.algorithms import AES, ARC4

# %%
# magic to make plots appear inline
# %matplotlib inline

# %%
# initialise objects
provi = prv.Providentia('foci_aeronet_BC.conf', section='AERONET1.5_FLAGL2')

# %%
# read and filter data from .conf 
provi.load()
# Out:
# Generating file trees...
# Reading data

# %%
# make a periodic plot
provi.plot('periodic-Mean', save='BC.png')

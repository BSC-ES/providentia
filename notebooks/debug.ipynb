# %%
# import Providentia
import providentia as prv

# %%
# magic to make plots appear inline
# %matplotlib inline

# %%
# initialise object
provi = prv.Providentia('debug.conf', section='DEBUG·Spain')

# %%
# download data
provi.download()
# Out:
# Starting Providentia download...

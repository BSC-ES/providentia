# %%
# import Providentia
import providentia as prv

# %%
# magic to make plots appear inline
# %matplotlib inline

# %%
# initialise object
provi = prv.Providentia('training.conf')

# %%
# read and filter data from .conf
provi.load()
# Out:
# Updating file tree /home/avilanov/software/providentia/settings/internal/ghost_filetree_1.6.json...
# Updating file tree /home/avilanov/software/providentia/settings/internal/nonghost_filetree.json...
# Reading data
#
# OBSERVATIONS
#  - EEA|sconco3
#  - EEA|sconcno2
# MODELS
#  - a59j-regional-006
#  - a59g-regional-000
# Resetting data filters to when class was initialised, loading TRAINING subsection filters.
# Filtering data

# %% [markdown]
# # Metadata

# %%
provi.plot('metadata', save_data=True)
# Out:
# ...
# Do you want to save plot data? ([y]/n)
# ...
# - File /home/avilanov/software/providentia/saved_data/metadata_observations_plot.csv

# %% [markdown]
# # Timeseries

# %%
provi.plot('timeseries', save_data=True)
# Out:
# ...
# Do you want to save plot data? ([y]/n)
# ...
# - File /home/avilanov/software/providentia/saved_data/timeseries_plot.csv

# %%
provi.plot('timeseries', bias=True, save_data=True)
# Out:
# ...
# Do you want to save bias_line data? ([y]/n)
#
# Do you want to save plot data? ([y]/n)
# ...
# - File /home/avilanov/software/providentia/saved_data/timeseries_bias_bias_line.csv
# - File /home/avilanov/software/providentia/saved_data/timeseries_bias_plot.csv

# %%
provi.plot('timeseries', annotate=True, save_data=True)
# Out:
# ...
# Do you want to save annotate data? ([y]/n)
#
# Do you want to save plot data? ([y]/n)
# ...
# - File /home/avilanov/software/providentia/saved_data/timeseries_annotate_ALL_annotate.csv
# - File /home/avilanov/software/providentia/saved_data/timeseries_annotate_plot.csv

# %%
provi.plot('timeseries-r-daily', save_data=True)
# Out:
# ...
# Do you want to save annotate data? ([y]/n)
#
# Do you want to save bias_line data? ([y]/n)
#
# Do you want to save plot data? ([y]/n)
# ...
# - File /home/avilanov/software/providentia/saved_data/timeseries-r-daily_ALL_annotate.csv
# - File /home/avilanov/software/providentia/saved_data/timeseries-r-daily_plot.csv
# - File /home/avilanov/software/providentia/saved_data/timeseries-r-daily_bias_line.csv

# %%
provi.plot('timeseries-r-daily', save_data=True, threshold=True)
# Out:
# ...
# Do you want to save annotate data? ([y]/n)
#
# Do you want to save bias_line data? ([y]/n)
#
# Do you want to save threshold data? ([y]/n)
#
# Do you want to save plot data? ([y]/n)
# ...
# - File /home/avilanov/software/providentia/saved_data/timeseries-r-daily_threshold_ALL_annotate.csv
# - File /home/avilanov/software/providentia/saved_data/timeseries-r-daily_threshold_plot.csv
# - File /home/avilanov/software/providentia/saved_data/timeseries-r-daily_threshold_bias_line.csv
# - File /home/avilanov/software/providentia/saved_data/timeseries-r-daily_threshold_threshold.csv

# %%
provi.plot('timeseries', smooth=True, save_data=True)
# Out:
# ...
# Do you want to save smooth data? ([y]/n)
#
# Do you want to save bias_line data? ([y]/n)
#
# Do you want to save threshold data? ([y]/n)
#
# Do you want to save annotate data? ([y]/n)
#
# Do you want to save plot data? ([y]/n)
# ...
# - File /home/avilanov/software/providentia/saved_data/timeseries_smooth_ALL_annotate.csv
# - File /home/avilanov/software/providentia/saved_data/timeseries_smooth_plot.csv
# - File /home/avilanov/software/providentia/saved_data/timeseries_smooth_smooth.csv
# - File /home/avilanov/software/providentia/saved_data/timeseries_smooth_bias_line.csv
# - File /home/avilanov/software/providentia/saved_data/timeseries_smooth_threshold.csv

# %% [markdown]
# # Maps

# %%
provi.plot('map-Median', networkspeci='EEA|sconco3', labela='observations', save_data=True)
# Out:
# ...
# Do you want to save plot data? ([y]/n)
# ...
# - File /home/avilanov/software/providentia/saved_data/map-Median_plot_observations.csv

# %%
provi.plot('map-r', networkspeci='EEA|sconco3', labela='observations', labelb='a59j-regional-006', save_data=True)
# Out:
# ...
# Do you want to save plot data? ([y]/n)
# ...
# - File /home/avilanov/software/providentia/saved_data/map-r_plot_observations-a59j-regional-006.csv

# %% [markdown]
# # Scatter

# %%
provi.plot('scatter', save_data=True)
# Out:
# ...
# Do you want to save plot data? ([y]/n)
# ...
# - File /home/avilanov/software/providentia/saved_data/scatter_plot.csv

# %%
provi.plot('scatter', regression=True, save_data=True)
# Out:
# ...
# Do you want to save regression data? ([y]/n)
#
# Do you want to save plot data? ([y]/n)
# ...
# - File /home/avilanov/software/providentia/saved_data/scatter_regression_plot.csv
# - File /home/avilanov/software/providentia/saved_data/scatter_regression_regression.csv

# %% [markdown]
# # Statsummary

# %%
provi.plot('statsummary', multispecies=True, bias=True, save_data=True)
# Out:
# ...
# Resetting data filters to when class was initialised, loading TRAINING subsection filters.
# Filtering data
# Resetting data filters to when class was initialised, loading TRAINING subsection filters.
# Filtering data
# ...
# Do you want to save plot data? ([y]/n)
# ...
# - File /home/avilanov/software/providentia/saved_data/statsummary_bias_multispecies_plot.csv

# %%
provi.plot('statsummary', save_data=True)
# Out:
# ...
# Resetting data filters to when class was initialised, loading TRAINING subsection filters.
# Filtering data
# Resetting data filters to when class was initialised, loading TRAINING subsection filters.
# Filtering data
# ...
# Do you want to save plot data? ([y]/n)
# ...
# - File /home/avilanov/software/providentia/saved_data/statsummary_plot.csv

# %%
provi.plot('statsummary', bias=True, save_data=True)
# Out:
# ...
# Resetting data filters to when class was initialised, loading TRAINING subsection filters.
# Filtering data
# Resetting data filters to when class was initialised, loading TRAINING subsection filters.
# Filtering data
# ...
# Do you want to save plot data? ([y]/n)
# ...
# - File /home/avilanov/software/providentia/saved_data/statsummary_bias_plot.csv

# %% [markdown]
# # Tables

# %%
provi.plot('table-Mean', multispecies=True, save_data=True)
# Out:
# ...
# Resetting data filters to when class was initialised, loading TRAINING subsection filters.
# Filtering data
# Resetting data filters to when class was initialised, loading TRAINING subsection filters.
# Filtering data
# ...
# Do you want to save plot data? ([y]/n)
# ...
# - File /home/avilanov/software/providentia/saved_data/table-Mean_multispecies_plot.csv

# %%
provi.plot('table-Mean', save_data=True)
# Out:
# ...
# Resetting data filters to when class was initialised, loading TRAINING subsection filters.
# Filtering data
# Resetting data filters to when class was initialised, loading TRAINING subsection filters.
# Filtering data
# ...
# Do you want to save plot data? ([y]/n)
# ...
# - File /home/avilanov/software/providentia/saved_data/table-Mean_plot.csv

# %% [markdown]
# # Heatmaps

# %%
provi.plot('heatmap-Mean', save_data=True)
# Out:
# ...
# Resetting data filters to when class was initialised, loading TRAINING subsection filters.
# Filtering data
# Axes(0.4,0.501587;0.6x0.285714)
# Resetting data filters to when class was initialised, loading TRAINING subsection filters.
# Filtering data
# ...
# Do you want to save plot data? ([y]/n)
# ...
# - File /home/avilanov/software/providentia/saved_data/heatmap-Mean_plot.csv

# %%
provi.plot('heatmap-Mean', multispecies=True, save_data=True)
# Out:
# ...
# Resetting data filters to when class was initialised, loading TRAINING subsection filters.
# Filtering data
# Axes(0.4,0.35873;0.6x0.571429)
# Resetting data filters to when class was initialised, loading TRAINING subsection filters.
# Filtering data
# ...
# Do you want to save plot data? ([y]/n)
# ...
# - File /home/avilanov/software/providentia/saved_data/heatmap-Mean_multispecies_plot.csv

# %% [markdown]
# # Distribution

# %%
provi.plot('distribution', save_data=True)
# Out:
# ...
# Do you want to save plot data? ([y]/n)
# ...
# - File /home/avilanov/software/providentia/saved_data/distribution_plot.csv

# %% [markdown]
# # Periodic plots

# %%
provi.plot('periodic-Mean', save_data=True)
# Out:
# ...
# Do you want to save plot_dayofweek data? ([y]/n)
#
# Do you want to save plot_hour data? ([y]/n)
#
# Do you want to save plot_month data? ([y]/n)
# ...
# - File /home/avilanov/software/providentia/saved_data/periodic-Mean_plot_hour.csv
# - File /home/avilanov/software/providentia/saved_data/periodic-Mean_plot_dayofweek.csv
# - File /home/avilanov/software/providentia/saved_data/periodic-Mean_plot_month.csv

# %%
provi.plot('periodic-violin')

# %%
provi.plot('periodic-violin', save_data=True)
# Out:
# ...
# Do you want to save Median_plot_dayofweek data? ([y]/n)
#
# Do you want to save violin_plot_dayofweek data? ([y]/n)
#
# Do you want to save Median_plot_hour data? ([y]/n)
#
# Do you want to save Median_plot_month data? ([y]/n)
#
# Do you want to save violin_plot_month data? ([y]/n)
#
# Do you want to save violin_plot_hour data? ([y]/n)
# ...
# - File /home/avilanov/software/providentia/saved_data/periodic-violin_violin_plot_hour.csv
# - File /home/avilanov/software/providentia/saved_data/periodic-violin_Median_plot_hour.csv
# - File /home/avilanov/software/providentia/saved_data/periodic-violin_violin_plot_dayofweek.csv
# - File /home/avilanov/software/providentia/saved_data/periodic-violin_Median_plot_dayofweek.csv
# - File /home/avilanov/software/providentia/saved_data/periodic-violin_violin_plot_month.csv
# - File /home/avilanov/software/providentia/saved_data/periodic-violin_Median_plot_month.csv

# %% [markdown]
# # FAIRMODE plots

# %%
provi.plot('fairmode-target', save_data=True)
# Out:
# ...
# Do you want to save plot data? ([y]/n)
# ...
# - File /home/avilanov/software/providentia/saved_data/fairmode-target_a59j-regional-006_plot.csv
# - File /home/avilanov/software/providentia/saved_data/fairmode-target_a59g-regional-000_plot.csv

# %%
provi.plot('fairmode-statsummary', save_data=True)
# Out:
# ...
# Do you want to save plot data? ([y]/n)
# ...
# - File /home/avilanov/software/providentia/saved_data/fairmode-statsummary_observations_plot_0.csv
# - File /home/avilanov/software/providentia/saved_data/fairmode-statsummary_observations_plot_1.csv
# - File /home/avilanov/software/providentia/saved_data/fairmode-statsummary_a59j-regional-006_plot_0.csv
# - File /home/avilanov/software/providentia/saved_data/fairmode-statsummary_a59j-regional-006_plot_1.csv
# - File /home/avilanov/software/providentia/saved_data/fairmode-statsummary_a59j-regional-006_plot_2.csv
# - File /home/avilanov/software/providentia/saved_data/fairmode-statsummary_a59j-regional-006_plot_3.csv
# - File /home/avilanov/software/providentia/saved_data/fairmode-statsummary_a59j-regional-006_plot_4.csv
# - File /home/avilanov/software/providentia/saved_data/fairmode-statsummary_a59j-regional-006_plot_5.csv
# - File /home/avilanov/software/providentia/saved_data/fairmode-statsummary_a59j-regional-006_plot_6.csv
# ...

# %% [markdown]
# # Taylor

# %%
provi.plot('taylor-r', save_data=True)
# Out:
# ...
# Do you want to save plot data? ([y]/n)
# ...
# - File /home/avilanov/software/providentia/saved_data/taylor-r_plot.csv

# %% [markdown]
# # Boxplot

# %%
provi.plot('boxplot', save_data=True)
# Out:
# ...
# Do you want to save plot data? ([y]/n)
# ...
# - File /home/avilanov/software/providentia/saved_data/boxplot_observations_plot_0.csv
# - File /home/avilanov/software/providentia/saved_data/boxplot_observations_plot_1.csv
# - File /home/avilanov/software/providentia/saved_data/boxplot_observations_plot_2.csv
# - File /home/avilanov/software/providentia/saved_data/boxplot_observations_plot_3.csv
# - File /home/avilanov/software/providentia/saved_data/boxplot_observations_plot_4.csv
# - File /home/avilanov/software/providentia/saved_data/boxplot_observations_plot_5.csv
# - File /home/avilanov/software/providentia/saved_data/boxplot_a59j-regional-006_plot_0.csv
# - File /home/avilanov/software/providentia/saved_data/boxplot_a59j-regional-006_plot_1.csv
# - File /home/avilanov/software/providentia/saved_data/boxplot_a59j-regional-006_plot_2.csv
# - File /home/avilanov/software/providentia/saved_data/boxplot_a59j-regional-006_plot_3.csv
# ...

# %%
# import Providentia
import providentia as prv

# %% [markdown]
# # Initialise object

# %%
provi = prv.Providentia('tutorial-0.conf')
# Out:
# ...
# Updating file tree /Users/denebowdalo/providentia/settings/internal/ghost_filetree_1.5.json...
# Updating file tree /Users/denebowdalo/providentia/settings/internal/nonghost_filetree.json...

# %% [markdown]
# # Run download mode

# %%
provi.download()
# Out:
# Starting Providentia download...
# Do you want to download from the BSC remote machine? (Otherwise, GHOST data will be retrieved from Zenodo) ([y]/n):  y
#
# There are some files that were already downloaded in a previous download, do you want to overwrite them (y/n)?  n
# Some experiments/observations were found but were not downloaded because the OVERWRITE option is set to 'n'.

# %% [markdown]
# # Run interpolation

# %%
provi.interpolate()
# Out:
# ...
#
# Variables used for the interpolation:
#
# ghost_version: 1.5
# start_date: 201801
# end_date: 201901
# experiments:
#  - cams61_emep_ph2-eu-000 (EMEP)
#  - cams61_monarch_ph2-eu-000 (MONARCH)
#  - cams61_silam_ph2-eu-000 (SILAM)
# species: ['sconco3']
# network: ['EBAS']
# resolution: ['hourly']
# model_resolution: []
# forecast: []
# interp_spinup_timesteps: 0
# interp_model_downsampling: mean
# interp_model_upsampling: fill
# interp_n_neighbours: 4
# interp_reverse_vertical_orientation: False
# interp_chunk_size: 16
# interp_job_array_limit: 100
# exp_root: /Users/denebowdalo/data/providentia/exp
# ghost_root: /Users/denebowdalo/data/providentia/obs/ghost
# nonghost_root: /Users/denebowdalo/data/providentia/obs/nonghost
# exp_to_interp_root: /Users/denebowdalo/data/providentia/exp_to_interp
# interp_multiprocessing: True
#
# MODEL: EMEP
#
# 156 observation files for EBAS and hourly resolution were found in /Users/denebowdalo/data/providentia/obs/ghost/EBAS/1.5/hourly/sconco3.
# ...

# %% [markdown]
# # Create report

# %%
provi.report()
# Out:
# Creating a Providentia Report...
# Starting to create PDF for LOCAL section
# Updating file tree /Users/denebowdalo/providentia/settings/internal/ghost_filetree_1.5.json...
# Updating file tree /Users/denebowdalo/providentia/settings/internal/nonghost_filetree.json...
#
# OBSERVATIONS
#  - EBAS|sconco3
# EXPERIMENTS
#  - cams61_emep_ph2-eu-000 (EMEP)
#  - cams61_monarch_ph2-eu-000 (MONARCH)
#  - cams61_silam_ph2-eu-000 (SILAM)
#
#
# Filtering data for LOCAL·All subsection
# Making EBAS|sconco3, LOCAL·All summary plots
# Making summary boxplot_multispecies
#
# Filtering data for LOCAL·France subsection
# Making EBAS|sconco3, LOCAL·France summary plots
# Making summary boxplot_multispecies
#
# Filtering data for LOCAL·Germany subsection
# Making EBAS|sconco3, LOCAL·Germany summary plots
# Making summary boxplot_multispecies
#
# Filtering data for LOCAL·Spain subsection
# Making EBAS|sconco3, LOCAL·Spain summary plots
# Making summary boxplot_multispecies
#
# ...

# %% [markdown]
# # Open dashboard

# %%
provi.dashboard()

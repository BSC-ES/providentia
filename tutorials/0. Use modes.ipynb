# %%
# import Providentia
import providentia as prv

# %% [markdown]
# # Initialise object

# %%
provi = prv.Providentia('tutorial-0.conf')
# Out:
# ...
# Updating file tree /Users/denebowdalo/providentia/settings/internal/ghost_filetree_1.5.json...
# Updating file tree /Users/denebowdalo/providentia/settings/internal/nonghost_filetree.json...

# %% [markdown]
# # Run download mode

# %%
provi.download()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 provi.download()
#
# File ~/providentia/providentia/library.py:1547, in Providentia.download(self, **kwargs)
#    1544 if not valid_config:
#    1545     return
# -> 1547 from .download import main
#    1549 kwargs['download'] = True
#    1550 parent_kwargs = copy.deepcopy(self.kwargs)
#
# File ~/providentia/providentia/download.py:18
#      15 from tqdm import tqdm
#      16 import yaml
# ---> 18 from .actris import Actris
#      19 from .cams import (Cams, cams_options)
#      20 from providentia.auxiliar import CURRENT_PATH, join
#
# File ~/providentia/providentia/actris.py:39
#      35 variable_mapping = yaml.safe_load(open(join(
#      36     PROVIDENTIA_ROOT, 'settings', 'internal', 'actris', 'variable_mapping.yaml')))
#      37 variable_mapping = {k: v for k,
# ...

# %% [markdown]
# # Run interpolation

# %%
provi.interpolate()
# Out:
# ...
#
# Variables used for the interpolation:
#
# ghost_version: 1.5
# start_date: 20180101
# end_date: 20190101
# models:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 provi.interpolate()
#
# File ~/providentia/providentia/library.py:1595, in Providentia.interpolate(self, **kwargs)
#    1593     parent_kwargs = copy.deepcopy(self.kwargs)
#    1594     parent_kwargs.update(kwargs)
# -> 1595     interpolation.main(**parent_kwargs)
#    1596 finally:
#    1597     # reset stdout
#    1598     sys.stdout = orig_stdout
#
# File ~/providentia/providentia/interpolation/experiment_interpolation_submission.py:1378, in main(**kwargs)
#    1368 """
#    1369 Executes the interpolation job lifecycle by gathering tasks and selecting the execution backend.
#    1370
# ...

# %% [markdown]
# # Create report

# %%
provi.report()

# %% [markdown]
# # Open dashboard

# %%
provi.dashboard()
# Out:
# Updating file tree /Users/denebowdalo/providentia/settings/internal/ghost_filetree_1.5.json...
# Updating file tree /Users/denebowdalo/providentia/settings/internal/nonghost_filetree.json...
# Starting Providentia dashboard...
#
# OBSERVATIONS
#  - EBAS|sconco3
# MODELS
#  - cams61_emep_ph2-eu-000 (EMEP)
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0

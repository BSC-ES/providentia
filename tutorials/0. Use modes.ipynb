# %%
# import Providentia
import providentia as prv

# %% [markdown]
# # Initialise object

# %%
provi = prv.Providentia('tutorial-0.conf')

# %% [markdown]
# # Run download mode

# %%
provi.download()
# Out:
# Starting Providentia download...
# Experiments were detected in the configuration file. Do you want to download the interpolated versions? (Otherwise, the non-interpolated experiments will be downloaded) ([y]/n):  n
#
# Do you want to download from the BSC remote machine? (Otherwise, GHOST data will be retrieved from Zenodo) ([y]/n):
# ----------------------------------------
#
# ...
#
# EBAS observations to download (1):
#
#   - /home/avilanov/data/providentia/obs/ghost/EBAS/1.5/hourly/sconco3, source: /gpfs/projects/bsc32/AC_cache/obs/ghost/EBAS/1.5/hourly/sconco3 (storage5)
# ...
# ----------------------------------------
#
# ...
#
# cams61_emep_ph2-eu-000 experiment data to download (1):
#
#   - /home/avilanov/data/providentia/exp_to_interp/ecmwf/cams61/cams61_emep_ph2/eu/hourly/sconco3, source: /gpfs/archive/bsc32/esarchive/recon/ecmwf/cams61/cams61_emep_ph2/eu/hourly/sconco3 (storage5)
# ...

# %% [markdown]
# # Run interpolation

# %%
provi.interpolate()
# Out:
# ...
#
# Variables used for the interpolation:
#
# ghost_version: 1.5
# start_date: 201801
# end_date: 201901
# experiments:
#  - cams61_emep_ph2-eu-000 (EMEP)
# species: ['sconco3']
# network: ['EBAS']
# resolution: ['hourly']
# forecast: []
# interp_spinup_timesteps: 0
# interp_experiment_downsampling: mean
# interp_experiment_upsampling: None
# interp_n_neighbours: 4
# interp_reverse_vertical_orientation: False
# interp_chunk_size: 16
# interp_job_array_limit: 100
# exp_root: /home/avilanov/data/providentia/exp
# ghost_root: /home/avilanov/data/providentia/obs/ghost
# nonghost_root: /home/avilanov/data/providentia/obs/nonghost
# exp_to_interp_root: /home/avilanov/data/providentia/exp_to_interp
# interp_multiprocessing: True
#
# START INTERPOLATION
#
# MODEL: EMEP
#
# 120 observation files for EBAS and hourly resolution were found in /home/avilanov/data/providentia/obs/ghost/EBAS/1.5/hourly/sconco3.
# ...

# %% [markdown]
# # Create report

# %%
provi.report()
# Out:
# Creating a Providentia Report...
# Starting to create PDF for LOCAL section
# Generating file trees...
#
# OBSERVATIONS
#  - EBAS|sconco3
# EXPERIMENTS
#  - cams61_emep_ph2-eu-000 (EMEP)
#
#
# Filtering data for LOCAL·All subsection
# Making EBAS|sconco3, LOCAL·All summary plots
# Making summary timeseries
#
# Filtering data for LOCAL·France subsection
# Making EBAS|sconco3, LOCAL·France summary plots
# Making summary timeseries
#
# Filtering data for LOCAL·Germany subsection
# Making EBAS|sconco3, LOCAL·Germany summary plots
# Making summary timeseries
#
# Filtering data for LOCAL·Spain subsection
# Making EBAS|sconco3, LOCAL·Spain summary plots
# Making summary timeseries
#
# Filtering data for LOCAL·UK subsection
# Making EBAS|sconco3, LOCAL·UK summary plots
# Making summary timeseries
#
# Writing PDF in /home/avilanov/software/providentia/reports/local.pdf
#
# Compressing PDF

# %% [markdown]
# # Open dashboard

# %%
provi.dashboard()
# Out:
# Generating file trees...
# Starting Providentia dashboard...
#
# OBSERVATIONS
#  - EBAS|sconco3
# EXPERIMENTS
#  - cams61_emep_ph2-eu-000 (EMEP)
#  - cams61_monarch_ph2-eu-000 (MONARCH)
#  - cams61_silam_ph2-eu-000 (SILAM)
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0

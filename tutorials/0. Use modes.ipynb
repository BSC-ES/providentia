# %%
# import Providentia
import providentia as prv

# %% [markdown]
# # Initialise object

# %%
provi = prv.Providentia('library.conf')

# %% [markdown]
# # Run download mode

# %%
provi.download()
# Out:
# Starting Providentia download...
# There are some files that were already downloaded in a previous download, do you want to overwrite them ([y]/n)?  y
# ----------------------------------------
#
# ...
#
# EBAS-EMEP observations to download:
#
#   - /home/avilanov/data/providentia/obs/ghost/EBAS-EMEP/1.5/hourly/sconco3
# ...
# ----------------------------------------
#
# ...
#
# dataset = 'cams-europe-air-quality-reanalyses'
# request = {
# 'variable' : 'ozone',
# 'year' : '2018',
# 'month' : '01',
# 'type' : 'validated_reanalysis',
# 'model' : 'ensemble',
# 'level' : '0',
# }
#
# ...
# Formatting /home/avilanov/data/providentia/mod_to_interp/cams_reanalysis_ensemble_validated/regional/hourly/sconco3/sconco3_201801.nc

# %% [markdown]
# # Run interpolation

# %%
provi.interpolate()
# Out:
# ...
#
# Variables used for the interpolation:
#
# ghost_version: 1.5
# start_date: 201801
# end_date: 201802
# models:
#  - cams_reanalysis_ensemble_validated-regional-000 (CAMS)
# species: ['sconco3']
# network: ['EBAS-EMEP']
# resolution: ['hourly']
# model_resolution: ['hourly']
# forecast: []
# interp_spinup_timesteps: 0
# interp_model_downsampling: mean
# interp_model_upsampling: fill
# interp_n_neighbours: 4
# interp_reverse_vertical_orientation: False
# interp_chunk_size: 16
# interp_job_array_limit: 100
# mod_root: /home/avilanov/data/providentia/mod
# ghost_root: /home/avilanov/data/providentia/obs/ghost
# nonghost_root: /home/avilanov/data/providentia/obs/nonghost
# mod_to_interp_root: /home/avilanov/data/providentia/mod_to_interp
# interp_multiprocessing: True
#
# MODEL: CAMS
#
# 2 observation files for EBAS-EMEP and hourly resolution were found in /home/avilanov/data/providentia/obs/ghost/EBAS-EMEP/1.5/hourly/sconco3.
# ...

# %% [markdown]
# # Create report

# %%
provi.report()
# Out:
# Creating a Providentia Report...
# Starting to create PDF for LOCAL section
# Updating file tree /home/avilanov/software/providentia/settings/internal/ghost_filetree_1.5.json...
# Updating file tree /home/avilanov/software/providentia/settings/internal/nonghost_filetree.json...
#
# OBSERVATIONS
#  - EBAS-EMEP|sconco3
# MODELS
#  - cams_reanalysis_ensemble_validated-regional-000 (CAMS)
#
#
# Filtering data for LOCAL·All subsection
# Making EBAS-EMEP|sconco3, LOCAL·All summary plots
# Making summary boxplot_multispecies
#
# Filtering data for LOCAL·France subsection
# Making EBAS-EMEP|sconco3, LOCAL·France summary plots
# Making summary boxplot_multispecies
#
# Filtering data for LOCAL·Germany subsection
# Making EBAS-EMEP|sconco3, LOCAL·Germany summary plots
# Making summary boxplot_multispecies
#
# Filtering data for LOCAL·Spain subsection
# Making EBAS-EMEP|sconco3, LOCAL·Spain summary plots
# Making summary boxplot_multispecies
#
# Filtering data for LOCAL·UK subsection
# ...

# %% [markdown]
# # Open dashboard

# %%
provi.dashboard()
# Out:
# Updating file tree /home/avilanov/software/providentia/settings/internal/ghost_filetree_1.5.json...
# Updating file tree /home/avilanov/software/providentia/settings/internal/nonghost_filetree.json...
# Starting Providentia dashboard...
#
# OBSERVATIONS
#  - EBAS-EMEP|sconco3
# MODELS
#  - cams_reanalysis_ensemble_validated-regional-000 (CAMS)
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0

# %%
import os
import numpy as np
import pandas as pd
import requests
from netCDF4 import Dataset, num2date
import xarray as xr
from datetime import datetime, timedelta
import netCDF4
from providentia.auxiliar import CURRENT_PATH
from pathlib import Path

# %%
def show_variable(var):
    print(f"• Variable: {var.name}")
    print(f"• Data type: {var.dtype}")
    print(f"• Dimensions: {var.dimensions}")
    print(f"• Shape: {var.shape}")
    print("• Attributes:")
    if var.ncattrs():
        for attr in var.ncattrs():
            print(f"   - {attr}: {getattr(var, attr)}")
    print()

# %%
goal_path = "/home/pserrano/data/providentia/mod_to_interp/era5_reanalysis/global/hourly/u10/u10_201801.nc"
goal_path="/home/pserrano/format_bug/providentia/data_2000/era5_2000_01_19.nc"
goal_path= "/home/pserrano/data/providentia/mod_to_interp/.temp/era5_reanalysis/global/hourly/aswin/data_stream-oper_stepType-accum.nc"
goal_path = "/home/pserrano/data/providentia/mod_to_interp/era5_reanalysis/global/hourly/cld/cld_201801.nc"
goal_path = "/home/pserrano/format_bug/providentia/data_2000/era5_2000_01_17.nc"
goal_path = "/home/pserrano/data/providentia/mod_to_interp/era5_reanalysis/global/hourly/photi/photi_201801.nc"
#goal_path = "/home/pserrano/data/providentia/mod_to_interp/era5_reanalysis/global/hourly/clddf/clddf_201801.nc"
#goal_path = "/home/pserrano/data/providentia/mod_to_interp/era5_reanalysis/global/hourly/photi/photi_201801.nc"
with Dataset(goal_path, "r") as goal_file:
    for v in goal_file.variables.keys():
        show_variable(goal_file.variables[v])
        # print(goal_file.variables[v][:])
        print("------------------------------------------\n")
    print(f"• Dimensions: {list(goal_file.dimensions.keys())}")
# Out:
# • Variable: time
# • Data type: int64
# • Dimensions: ('time',)
# • Shape: (744,)
# • Attributes:
#    - calendar: proleptic_gregorian
#    - units: hours since 2018-01-01
#
# ------------------------------------------
#
# • Variable: latitude
# • Data type: float64
# • Dimensions: ('latitude',)
# • Shape: (721,)
# • Attributes:
#
# ------------------------------------------
#
# • Variable: longitude
# • Data type: float64
# • Dimensions: ('longitude',)
# • Shape: (1440,)
# • Attributes:
#
# ------------------------------------------
#
# • Variable: photi
# • Data type: float32
# • Dimensions: ('time', 'latitude', 'longitude')
# • Shape: (744, 721, 1440)
# • Attributes:
#    - coordinates: latitude longitude
#    - grid_mapping: crs
#    - units: J m-2
#
# ------------------------------------------
#
# • Variable: crs
# • Data type: uint8
# • Dimensions: ()
# • Shape: ()
# • Attributes:
#    - grid_mapping_name: latitude_longitude
#    - semi_major_axis: 6371000.0
# ...

# %%
goal_path = "/home/pserrano/data/providentia/mod/1.6/a9yd-regional-000/daily/pm2p5/XVPCA/pm2p5_202308.nc"
with Dataset(goal_path, "r") as goal_file:
    for v in goal_file.variables.keys():
        show_variable(goal_file.variables[v])
        print(goal_file.variables[v][:])
        print("------------------------------------------\n")
    print(f"• Dimensions: {list(goal_file.dimensions.keys())}")
# Out:
# • Variable: grid_edge_latitude
# • Data type: float64
# • Dimensions: ('grid_edge',)
# • Shape: (1045,)
# • Attributes:
#    - standard_name: grid edge latitude
#    - long_name: grid edge latitude
#    - units: decimal degrees North
#    - description: Latitude coordinate along edge of grid domain (going clockwise around grid boundary from bottom-left corner).
#    - axis: Y
#
# [33.4462254  33.4960049  33.54578368 ... 33.45549037 33.4508743
#  33.4462254 ]
# ------------------------------------------
#
# • Variable: grid_edge_longitude
# • Data type: float64
# • Dimensions: ('grid_edge',)
# • Shape: (1045,)
# • Attributes:
#    - standard_name: grid edge longitude
#    - long_name: grid edge longitude
#    - units: decimal degrees East
#    - description: Longitude coordinate along edge of grid domain (going clockwise around grid boundary from bottom-left corner).
#    - axis: X
#
# [-11.98159339 -11.98721885 -11.99285074 ... -11.86292143 -11.92226055
#  -11.98159339]
# ...

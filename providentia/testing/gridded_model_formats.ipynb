# %%
# Run this on Nord4, as we have most experiments in esarchive
import os
import yaml

# %%
PROVIDENTIA_ROOT = os.path.abspath("../..")
PROVIDENTIA_ROOT
# Out:
# '/gpfs/scratch/bsc32/bsc032781/software/providentia'

# %%
interp_experiments = yaml.safe_load(open(os.path.join(PROVIDENTIA_ROOT, 'settings', 'interp_models.yaml')))
mapping_species =  yaml.safe_load(open(os.path.join(PROVIDENTIA_ROOT, 'settings', 'mapping_species.yaml')))

domains = ["ip", "d03", "d01", "regional", "eu", "reg", "ex", "bcn", "cat", "d02", "global","regional_i01", "regional_i02", "regional_i03"] #interpolation
species = ['sconco3', 'sconcno', 'sconcno2', 'sconcso2', 'sconcco', 'sconcch4', 'sconcc2h2', 'sconcglyox', 'sconcc2h4', 'sconcald2', 'sconcc2h6', 'sconcetoh', 'sconcc3h6', 'sconcc3h8', 'sconcc4h6', 'sconcc4h8', 'sconcc4h10', 'sconcisop', 'sconcc5h12', 'sconcc6h6', 'sconcc6h14', 'sconcc7h8', 'sconcxyl', 'sconcmpxyl', 'sconcmxyl', 'sconcpxyl', 'sconcoxyl', 'sconcc9h12', 'sconcc10h16', 'sconcbap', 'sconcnmvoc', 'sconcvoc', 'sconnmhc', 'sconchc', 'sconcnh3', 'sconchno3', 'sconcpan', 'sconchcho', 'sconchcl', 'sconchf', 'sconch2s', 'sconchggem', 'sconchggom', 'sconchgtgm', 'sconcal', 'sconcas', 'sconcbappm', 'sconcbc', 'sconcc', 'sconcca', 'sconccd', 'sconccl', 'sconccobalt', 'sconccr', 'sconccu', 'sconcdu', 'sconcec', 'sconcfe', 'sconchg', 'sconck', 'sconcmg', 'sconcmn', 'sconcmsa', 'sconcna', 'sconcnh4', 'sconcnh4no3', 'sconcni', 'sconcno3', 'sconcoc', 'sconcpb', 'sconcse', 'sconcso4', 'sconcso4nss', 'sconcso4ss', 'sconcv', 'sconczn', 'absco370', 'absco467', 'absco470', 'absco520', 'absco522', 'absco525', 'absco528', 'absco530', 'absco550', 'absco565', 'absco590', 'absco637', 'absco652', 'absco660', 'absco670', 'absco880', 'absco950', 'absae370-880', 'absae370-950', 'absae467-652', 'absae467-660', 'lbsco450', 'lbsco520', 'lbsco525', 'lbsco530', 'lbsco532', 'lbsco550', 'lbsco635', 'lbsco700', 'lbsco850', 'lsco450', 'lsco520', 'lsco525', 'lsco530', 'lsco532', 'lsco550', 'lsco635', 'lsco700', 'lsco850', 'lsae450-635', 'lsae450-700', 'lbsf450', 'lbsf520', 'lbsf525', 'lbsf530', 'lbsf532', 'lbsf550', 'lbsf635', 'lbsf700', 'lbsf850', 'asy525', 'asy550', 'pm10', 'pm10al', 'pm10as', 'pm10bap', 'pm10bc', 'pm10c', 'pm10ca', 'pm10cd', 'pm10cl', 'pm10cobalt', 'pm10cr', 'pm10cu', 'pm10du', 'pm10ec', 'pm10fe', 'pm10hg', 'pm10k', 'pm10mg', 'pm10mn', 'pm10msa', 'pm10na
'extod870aerocoarse', 'extod870aerofine', 'extod1020aero', 'extod1020aerocoarse', 'extod1020aerofine', 'extae440-675aero', 'extae440-870aero', 'absod440aero', 'absod550aero', 'absod675aero', 'absod870aero', 'absod1020aero', 'absae440-675aero', 'absae440-870aero', 'absae675-870aero', 'abswdaeaero', 'absod440bc', 'absae440-870bc', 'absod440brc', 'lsae440-675aero', 'sca440aero', 'sca550aero', 'sca675aero', 'sca870aero', 'sca1020aero', 'scaae440-675aero', 'asy440aero', 'asy440aerocoarse', 'asy440aerofine', 'asy675aero', 'asy675aerocoarse', 'asy675aerofine', 'asy870aero', 'asy870aerocoarse', 'asy870aerofine', 'asy1020aero', 'asy1020aerocoarse', 'asy1020aerofine', 'sphaero', 'rinreal440', 'rinreal675', 'rinreal870', 'rinreal1020', 'rinimag440', 'rinimag675', 'rinimag870', 'rinimag1020', 'vconcaero', 'vconcaerocoarse', 'vconcaerofine', 'vconcaerobin1', 'vconcaerobin2', 'vconcaerobin3', 'vconcaerobin4', 'vconcaerobin5', 'vconcaerobin6', 'vconcaerobin7', 'vconcaerobin8', 'vconcaerobin9', 'vconcaerobin10', 'vconcaerobin11', 'vconcaerobin12', 'vconcaerobin13', 'vconcaerobin14', 'vconcaerobin15', 'vconcaerobin16', 'vconcaerobin17', 'vconcaerobin18', 'vconcaerobin19', 'vconcaerobin20', 'vconcaerobin21', 'vconcaerobin22']
species += [i[0] for i in mapping_species.values()]
resolutions = ['hourly', '3hourly', '6hourly', 'hourly_instantaneous',
               '3hourly_instantaneous', '6hourly_instantaneous',
               'daily', 'monthly']

# %% [markdown]
# Get all the possible absolute paths to the nc files directories by filtering the domain, species, resolution, etc.

# %%
def search_paths():
    possibles_paths = []

    for experiment_dict in interp_experiments.values():
        for exp in experiment_dict["models"]:
            for path in experiment_dict["paths"]:
                for domain in domains:
                    full_path = os.path.join(path,exp,domain)
                    isdir = os.path.isdir(full_path)
                    if not isdir:
                        continue
                        # if full_path.startswith("/gpfs"):
                        #     print(full_path)
                        # experiments.append(f"{exp}-{domain}")
                    
                    for res in resolutions:
                        for spec in species:
                            full_path = os.path.join(path,exp,domain,res,spec)
                            isdir = os.path.isdir(full_path)
                            if isdir:
                                possibles_paths.append(full_path)
                                
    return possibles_paths

# %%
possibles_paths = search_paths()

# %% [markdown]
# Get the different nc files and analyse the format

# %%
nc_files_dict = {}
for path in possibles_paths:
    for file in os.listdir(path):
        nc_files_dict[file] = path

# %%
nc_files_dict
# Out:
# {'sconco3-000_2019050900.nc': '/esarchive/exp/monarch/a6fr/regional_i01/hourly/sconco3',
#  'sconco3-000_2019061700.nc': '/esarchive/exp/monarch/a6fr/regional_i01/hourly/sconco3',
#  'sconco3-000_2019050100.nc': '/esarchive/exp/monarch/a6fr/regional_i01/hourly/sconco3',
#  'sconco3-000_2019053100.nc': '/esarchive/exp/monarch/a6fr/regional_i01/hourly/sconco3',
#  'sconco3-000_2019021500.nc': '/esarchive/exp/monarch/a6fr/regional_i01/hourly/sconco3',
#  'sconco3-000_2019101900.nc': '/esarchive/exp/monarch/a6fr/regional_i01/hourly/sconco3',
#  'sconco3-000_2019041900.nc': '/esarchive/exp/monarch/a6fr/regional_i01/hourly/sconco3',
#  'sconco3-000_2019021000.nc': '/esarchive/exp/monarch/a6fr/regional_i01/hourly/sconco3',
#  'sconco3-000_2019033100.nc': '/esarchive/exp/monarch/a6fr/regional_i01/hourly/sconco3',
#  'sconco3-000_2019090200.nc': '/esarchive/exp/monarch/a6fr/regional_i01/hourly/sconco3',
# ...

# %%
nc_files_dict = {}
for path in possibles_paths:
    for file in os.listdir(path):
        # filter the files that do not start with the species
        species = path.split("/")[-1]
        if file.startswith(species):
            nc_files_dict[file] = path

# %%
nc_files_dict
# Out:
# {'sconco3-000_2019050900.nc': '/esarchive/exp/monarch/a6fr/regional_i01/hourly/sconco3',
#  'sconco3-000_2019061700.nc': '/esarchive/exp/monarch/a6fr/regional_i01/hourly/sconco3',
#  'sconco3-000_2019050100.nc': '/esarchive/exp/monarch/a6fr/regional_i01/hourly/sconco3',
#  'sconco3-000_2019053100.nc': '/esarchive/exp/monarch/a6fr/regional_i01/hourly/sconco3',
#  'sconco3-000_2019021500.nc': '/esarchive/exp/monarch/a6fr/regional_i01/hourly/sconco3',
#  'sconco3-000_2019101900.nc': '/esarchive/exp/monarch/a6fr/regional_i01/hourly/sconco3',
#  'sconco3-000_2019041900.nc': '/esarchive/exp/monarch/a6fr/regional_i01/hourly/sconco3',
#  'sconco3-000_2019021000.nc': '/esarchive/exp/monarch/a6fr/regional_i01/hourly/sconco3',
#  'sconco3-000_2019033100.nc': '/esarchive/exp/monarch/a6fr/regional_i01/hourly/sconco3',
#  'sconco3-000_2019090200.nc': '/esarchive/exp/monarch/a6fr/regional_i01/hourly/sconco3',
# ...

# %% [markdown]
# # Possible formats
# Two main groups:
# 1. species-ensopt_,
#     1. species-ensopt_date.nc E.g. loaddu-000_2023052013.nc (common)
#     2. species-ensopt_date_ending.nc E.g. loaddu-000_2023052012_horizontal.nc Possible endings: {'diff.nc', 'horizontal.nc', 'an.nc'} (common)
# 2. species_
#     1. species_date.nc E.g. loaddu_2023052013.nc (common)
#     2. species_ensopt_date.nc E.g. loaddu_006_2023052013.nc (rare, error i guess)
#     3. species_date_av_an.nc E.g. loaddu_2023052013_av_an.nc (rare, all endings are av_an )

# %% [markdown]
# ## species-ensemble_date.nc (example: sconco3-000_2019050900.nc)

# %%
fun = lambda file :(file.count("-"),file.count("_")) == (1,1)
nc_files = list(filter(fun, nc_files_dict.keys()))
nc_files
# Out:
# ['sconco3-000_2019050900.nc',
#  'sconco3-000_2019061700.nc',
#  'sconco3-000_2019050100.nc',
#  'sconco3-000_2019053100.nc',
#  'sconco3-000_2019021500.nc',
#  'sconco3-000_2019101900.nc',
#  'sconco3-000_2019041900.nc',
#  'sconco3-000_2019021000.nc',
#  'sconco3-000_2019033100.nc',
#  'sconco3-000_2019090200.nc',
#  'sconco3-000_2019040700.nc',
#  'sconco3-000_2019072300.nc',
#  'sconco3-000_2018122900.nc',
#  'sconco3-000_2019021700.nc',
#  'sconco3-000_2019122500.nc',
#  'sconco3-000_2019091300.nc',
#  'sconco3-000_2019020100.nc',
#  'sconco3-000_2019061400.nc',
#  'sconco3-000_2019013100.nc',
#  'sconco3-000_2019080100.nc',
#  'sconco3-000_2019091800.nc',
#  'sconco3-000_2019030600.nc',
#  'sconco3-000_2019070800.nc',
#  'sconco3-000_2019082600.nc',
#  'sconco3-000_2019051800.nc',
#  'sconco3-000_2019102600.nc',
#  'sconco3-000_2019092000.nc',
#  'sconco3-000_2019042200.nc',
#  'sconco3-000_2019012800.nc',
#  'sconco3-000_2019100500.nc',
#  'sconco3-000_2019020900.nc',
# ...

# %% [markdown]
# ## species-ensemble_date_ending.nc (example: od550du-006_2018082003_an.nc)

# %%
fun = lambda file :(file.count("-"),file.count("_")) == (1,2)
nc_files = list(filter(fun, nc_files_dict.keys()))
nc_files
# Out:
# ['od550du-006_2018082003_an.nc',
#  'od550du-000_2018101003_an.nc',
#  'od550du-006_2018121903_an.nc',
#  'od550du-008_2018060203_an.nc',
#  'od550du-000_2018101403_an.nc',
#  'od550du-007_2018102303_an.nc',
#  'od550du-003_2018012303_an.nc',
#  'od550du-003_2018013103_an.nc',
#  'od550du-000_2018011203_an.nc',
#  'od550du-009_2018081503_an.nc',
#  'od550du-008_2018043003_an.nc',
#  'od550du-001_2018052203_an.nc',
#  'od550du-005_2018112603_an.nc',
#  'od550du-007_2018043003_an.nc',
#  'od550du-006_2018010103_an.nc',
#  'od550du-003_2018101303_an.nc',
#  'od550du-003_2018102103_an.nc',
#  'od550du-010_2018020603_an.nc',
#  'od550du-009_2018091303_an.nc',
#  'od550du-003_2018081203_an.nc',
#  'od550du-003_2018122003_an.nc',
#  'od550du-009_2018092303_an.nc',
#  'od550du-001_2018020503_an.nc',
#  'od550du-003_2018122403_an.nc',
#  'od550du-006_2018051903_an.nc',
#  'od550du-007_2018112303_an.nc',
#  'od550du-007_2018020703_an.nc',
#  'od550du-007_2018072303_an.nc',
# ...

# %% [markdown]
# ## species_yearmonthdayhour.nc (example: pm10_2017092100.nc)

# %%
fun = lambda file :(file.count("-"), file.count("_") and len(file.split("_")[1]) == 13) == (0,1)
nc_files = list(filter(fun, nc_files_dict.keys()))
nc_files
# Out:
# ['pm10_2017092100.nc',
#  'pm10_2017091600.nc',
#  'pm10_2016070400.nc',
#  'pm10_2017012300.nc',
#  'pm10_2017050400.nc',
#  'pm10_2016121800.nc',
#  'pm10_2016011600.nc',
#  'pm10_2016121700.nc',
#  'pm10_2017042300.nc',
#  'pm10_2016053000.nc',
#  'pm10_2017021000.nc',
#  'pm10_2016010900.nc',
#  'pm10_2017053100.nc',
#  'pm10_2017100200.nc',
#  'pm10_2016071500.nc',
#  'pm10_2017040100.nc',
#  'pm10_2017032100.nc',
#  'pm10_2017022300.nc',
#  'pm10_2016110500.nc',
#  'pm10_2017021700.nc',
#  'pm10_2017061900.nc',
#  'pm10_2017042200.nc',
#  'pm10_2016082900.nc',
#  'pm10_2016081400.nc',
#  'pm10_2016042800.nc',
#  'pm10_2016012700.nc',
#  'pm10_2017100500.nc',
#  'pm10_2017071800.nc',
#  'pm10_2016062500.nc',
#  'pm10_2017083000.nc',
#  'pm10_2016030200.nc',
#  'pm10_2016122000.nc',
#  'pm10_2016090500.nc',
#  'pm10_2017032600.nc',
#  'pm10_2017060900.nc',
#  'pm10_2016091900.nc',
#  'pm10_2016102000.nc',
#  'pm10_2016122800.nc',
#  'pm10_2016022600.nc',
#  'pm10_2017041500.nc',
# ...

# %% [markdown]
# ## species_yearmonth.nc (example: sconco3_201604.nc)

# %%
fun = lambda file :(file.count("-"), file.count("_") and len(file.split("_")[1]) == 9) == (0,1)
nc_files = list(filter(fun, nc_files_dict.keys()))
nc_files
# Out:
# ['sconco3_201604.nc',
#  'sconco3_201601.nc',
#  'sconco3_201608.nc',
#  'sconco3_201602.nc',
#  'sconco3_201609.nc',
#  'sconco3_201603.nc',
#  'sconco3_201610.nc',
#  'sconco3_201606.nc',
#  'sconco3_201612.nc',
#  'sconco3_201607.nc',
#  'sconco3_201611.nc',
#  'sconco3_201605.nc',
#  'sconcno2_201602.nc',
#  'sconcno2_201607.nc',
#  'sconcno2_201601.nc',
#  'sconcso2_201604.nc',
#  'sconcso2_201612.nc',
#  'sconcso2_201607.nc',
#  'sconcso2_201610.nc',
#  'sconcso2_201605.nc',
#  'sconcso2_201611.nc',
#  'sconcso2_201608.nc',
#  'sconcso2_201602.nc',
#  'sconcso2_201603.nc',
#  'sconcso2_201606.nc',
#  'sconcso2_201609.nc',
#  'sconcso2_201601.nc',
#  'pm10_201612.nc',
#  'pm10_201610.nc',
#  'pm10_201603.nc',
#  'pm10_201609.nc',
#  'pm10_201605.nc',
#  'pm10_201607.nc',
#  'pm10_201606.nc',
#  'pm10_201608.nc',
#  'pm10_201611.nc',
#  'pm10_201602.nc',
#  'pm10_201604.nc',
#  'pm10_201601.nc',
#  'pm2p5_201608.nc',
#  'pm2p5_201601.nc',
#  'pm2p5_201602.nc',
# ...

# %% [markdown]
# ## species_ensemble_date.nc (example: sconcno2_006_2022101900.nc)

# %%
fun = lambda file :(file.count("-"),file.count("_")) == (0,2)
nc_files = list(filter(fun, nc_files_dict.keys()))
nc_files
# Out:
# ['sconcno2_006_2022101900.nc',
#  'sconcno2_006_2022112800.nc',
#  'sconcno2_006_2022102000.nc',
#  'sconcno2_006_2022102600.nc',
#  'sconcno2_006_2022102700.nc',
#  'sconcno2_006_2021091300.nc',
#  'sconcno2_006_2021092100.nc',
#  'sconcno2_006_2021091200.nc',
#  'sconcno2_006_2021091900.nc',
#  'sconcno2_006_2022103000.nc',
#  'sconcno2_006_2021090800.nc',
#  'sconcno2_006_2021091100.nc',
#  'sconcno2_006_2021090500.nc',
#  'sconcno2_006_2021091600.nc',
#  'sconcno2_006_2021090600.nc',
#  'sconcno2_006_2022102400.nc',
#  'sconcno2_006_2021092400.nc',
#  'sconcno2_006_2022102100.nc',
#  'sconcno2_006_2021090300.nc',
#  'sconcno2_006_2022101800.nc',
#  'sconcno2_006_2021091500.nc',
#  'sconcno2_006_2021092200.nc',
#  'sconcno2_006_2021090900.nc',
#  'sconcno2_006_2022111000.nc',
#  'sconcno2_006_2021090700.nc',
#  'sconcno2_006_2021090400.nc',
#  'sconcno2_006_2021091800.nc',
#  'sconcno2_006_2022102800.nc',
#  'sconcno2_006_2022102900.nc',
#  'sconcno2_006_2022102500.nc',
# ...

# %% [markdown]
# ## species_date_av_an.nc (example: od550du_2020061400_av_an.nc)

# %%
fun = lambda file :(file.count("-"),file.count("_")) == (0,3)
nc_files = list(filter(fun, nc_files_dict.keys()))
nc_files
# Out:
# ['od550du_2020061400_av_an.nc',
#  'od550du_2020061500_av_an.nc',
#  'od550du_2020062200_av_an.nc',
#  'od550du_2020062300_av_an.nc',
#  'od550du_2020061300_av_an.nc',
#  'od550du_2020062900_av_an.nc',
#  'od550du_2020061900_av_an.nc',
#  'od550du_2020062100_av_an.nc',
#  'od550du_2020060400_av_an.nc',
#  'od550du_2020062600_av_an.nc',
#  'od550du_2020060300_av_an.nc',
#  'od550du_2020063000_av_an.nc',
#  'od550du_2020060900_av_an.nc',
#  'od550du_2020061800_av_an.nc',
#  'od550du_2020061100_av_an.nc',
#  'od550du_2020060100_av_an.nc',
#  'od550du_2020061600_av_an.nc',
#  'od550du_2020060600_av_an.nc',
#  'od550du_2020061200_av_an.nc',
#  'od550du_2020060500_av_an.nc',
#  'od550du_2020062800_av_an.nc',
#  'od550du_2020060200_av_an.nc',
#  'od550du_2020062000_av_an.nc',
#  'od550du_2020061000_av_an.nc',
#  'od550du_2020062700_av_an.nc',
#  'od550du_2020061700_av_an.nc',
#  'od550du_2020060800_av_an.nc',
#  'od550du_2020062400_av_an.nc',
#  'od550du_2020062500_av_an.nc',
# ...
